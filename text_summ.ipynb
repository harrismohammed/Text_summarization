# %% [markdown]
# ### Text Summarization to extract keywords and verify the originality of the content on Twitter
#
#  An unbelievable amount of data is being generated per second across the globe. It is possible to gather insights from these existing sources. Furthermore, a large portion of this data is either redundant or do not contain useful information. The most efficient way to get access to the most important part of the data, without having to sift through redundant and insignificant data, is to summarize the data in a way that it contains only non-redundant and useful information. This data can be of any form such as audio, video, images, and text. In this article, we will see how we can use automatic text summarization techniques to summarize text data and use the keywords from the summarized data to verify the originality of the content on Twitter.

# %% [markdown]
# - Automatic Text Summarization
#
# The main idea of summarization is to find a subset of the data which contains the "information" of the entire set. There are 2 general approaches to automatic text summarization
#
# a) Extraction based summarization
# b) Abstraction based summarization

# %% [markdown]
# ### Text Summarization using NLTK - Steps
#
# I shall explain the steps involved in text summarization with the help of an example. Here, I have considered an article from the internet.

# %%
# Import all the necessary libraries

import numpy as np
import json
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.chunk import tree2conlltags
from nltk import pos_tag

# %%
# Import data that needs to be summarized
f= open("test_summ.txt","r")
text = f.read()

# %%
print(text)
# Out:
# Elon Musk, under pressure from his lawyers and investors of Tesla, the company he co-founded, reached a deal with the Securities and Exchange Commission on Saturday to resolve securities fraud charges. The settlement will force Mr. Musk to step aside as chairman for three years and pay a $20 million fine.
#
# The S.E.C. announced the deal two days after it sued Mr. Musk in federal court for misleading investors over his post on Twitter last month that he had “funding secured” for a buyout of the electric-car company at $420 a share.
#
# The deal with the S.E.C. will allow him to remain as chief executive, something he could have jeopardized if he had gone to battle with the agency.
#
# It is not clear why Mr. Musk changed his mind so quickly.
#
# People familiar with the situation, who were not authorized to speak publicly on the matter, said lawyers for Mr. Musk and the company moved to reopen the talks with the S.E.C. on Friday. During that time, one of Tesla’s lawyers became instrumental in securing a deal with the S.E.C., according to a person familiar with the negotiations.
#
# The whipsaw events of the past few days followed a series of self-inflicted wounds by Mr. Musk.
#
# His tweet about taking his company private, along with attacks on critics on social media, raised concerns with investors about whether Mr. Musk has become too focused on criticism from so-called short-sellers who had been making bets against him and Tesla. The company has recently been struggling to meet audacious production goals for its Model 3 sedan.
#
# Mr. Musk is widely regarded by analysts and investors as the creative engine behind Tesla, and he has helped the company become one of the most valuable American carmakers. But Tesla has lurched from crisis to crisis over the past year, and has since scrambled to contain the fallout from Mr. Musk’s tweet.
#
# The company, whose shares have been hit hard since the S.E.C. filed the lawsuit, did not immediately comment on the settlement. On Friday, its stock dropped almost 14 percent.
#
# The terms of the settlement are slightly tougher than those that two people briefed on the talks said Mr. Musk had rejected on Thursday, which called for a two-year bar on serving as chairman and a $10 million fine.
#
# Tesla, which is also settling with the S.E.C., will pay a $20 million penalty. The company was not charged with any fraud.
#
# In addition, the company will add two independent directors and take steps to monitor Mr. Musk’s communications with investors. It will also create a permanent committee of independent directors to monitor disclosures and potential conflicts of interest.
#
# Jay Clayton, the S.E.C. chairman, said the settlement with Mr. Musk and Tesla sent a message that “when companies and corporate insiders make statements, they must act responsibly, including endeavoring to ensure the statements are not false or misleading.”
#
# In settling, Mr. Musk neither admitted nor denied misleading investors under the civil fraud charge, which means he cannot later say he did nothing wrong.
#
# The settlement with the S.E.C. faulted Tesla for failing to make sure that information important to investors was disclosed in a proper and timely manner.
#
# Serial entrepreneur Elon Musk wants to fundamentally change the way we live. But his path to success has been characterized by both great accomplishments and flirtations with failure.
#
# Mr. Musk had a good reason to reopen the settlement talks: The S.E.C., in suing him, had sought to bar him permanently from serving as a top executive or officer of Tesla or any other public company. Under the deal reached on Saturday, he will not only remain as chief executive, but will also stay on as a board member, just not as chairman.
#
# “The total package of remedies and relief announced today are specifically designed to address the misconduct at issue by strengthening Tesla’s corporate governance and oversight in order to protect investors,” said Stephanie Avakian, co-director of the S.E.C.’s enforcement division.
#
# Mr. Musk, according to people familiar with the negotiations, had been concerned about whether settling a civil fraud charge might affect the ability of Tesla and the other companies he runs, including SpaceX and the Boring Company, to raise money from investors in private placements and the debt markets.
#
# But a Tesla spokesman said the S.E.C. had granted waivers to all of those companies so his settlement would not be held against them.
#
# Waivers in such a situation are not uncommon, legal experts have said.
#
# A Tesla spokesman said that Mr. Musk, a billionaire, would be buying $20 million in Tesla stock. The amount of stock being bought by Mr. Musk matches the penalty the company has to pay under the settlement, which was filed in federal court in Manhattan.
#
# The S.E.C. reacted quickly after the Aug. 7 tweet, which caused an immediate surge in Tesla shares. Regulators served a subpoena on the company seeking information and moved to take testimony from Mr. Musk and others at the company, people familiar with the matter said.
#
# Negotiations toward an initial settlement began about a week ago, after the S.E.C. said it was planning to send an official notice to Mr. Musk and Tesla that it was considering filing an enforcement action, those briefed on the talks said. By their account, all the parties thought a deal had been reached by Wednesday evening, and the plan was for a settlement with Mr. Musk and Tesla to be announced on Thursday.
#
# Mr. Musk was said to have backed away from a settlement, in part, because he was concerned that he could not later tell investors that he had not done nothing wrong. But the settlement on Saturday requires him to do that.
#
# In a so-called “admit nor deny” settlement, a settling party cannot later disavow the terms of the settlement.
#
# After Mr. Musk was said to have rejected the deal on Thursday, his lawyers asked the S.E.C. to wait a couple of days so they could talk him into it, but the regulators said no, said another person familiar with the matter but not authorized to speak publicly.
#
# Once the S.E.C. sued Mr. Musk, his lawyers continued to talk to him about moving forward with a settlement and eventually he agreed, this person said.
#
# In the meantime, Mr. Musk had conversations with investors and friends like Mark Cuban, an entrepreneur who has had his own battles with the S.E.C., and they gave him a sense of how difficult it is to fight one of these suits, even if he eventually won, said people familiar with the negotiations.
#
# The parties worked much of Friday and Saturday to get a deal done.
#
# The settlement clears a big headache for Tesla, but other problems remain.
#
# The S.E.C. is continuing to look into the company’s past claims about its production goals. And now with Mr. Musk agreeing to step down as chairman, Tesla’s board must decide who should replace him.

# %% [markdown]
# #### Step 1 :
#
# Remove stop words(Any word that does not add a value to the meaning of a sentence). I have also cleaned my text accordingly. Tokenize the words in the document and find its corresponding normalized frequency.

# %%
def clean_text (text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"[-\"/;:|<>{}+=#_,']", "", text)
    text = re.sub(r"\n", "", text)
    text = re.sub(r"\xe2\x80\x9c", "", text)
    text = re.sub(r"\xe2\x80\x9d","", text)
    text = re.sub(r"\xe2\x80\x99","",text)
    return text

# %%
cleaned_text = []

cleaned_text.append(clean_text(text))

# %%
cleaned_text[0]
# Out:
# 'elon musk under pressure from his lawyers and investors of tesla the company he cofounded reached a deal with the securities and exchange commission on saturday to resolve securities fraud charges. the settlement will force mr. musk to step aside as chairman for three years and pay a $20 million fine.the s.e.c. announced the deal two days after it sued mr. musk in federal court for misleading investors over his post on twitter last month that he had funding secured for a buyout of the electriccar company at $420 a share.the deal with the s.e.c. will allow him to remain as chief executive something he could have jeopardized if he had gone to battle with the agency.it is not clear why mr. musk changed his mind so quickly.people familiar with the situation who were not authorized to speak publicly on the matter said lawyers for mr. musk and the company moved to reopen the talks with the s.e.c. on friday. during that time one of teslas lawyers became instrumental in securing a deal with the s.e.c. according to a person familiar with the negotiations.the whipsaw events of the past few days followed a series of selfinflicted wounds by mr. musk.his tweet about taking his company private along with attacks on critics on social media raised concerns with investors about whether mr. musk has become too focused on criticism from socalled shortsellers who had been making bets against him and tesla. the company has recently been struggling to meet audacious production goals for its model 3 sedan.mr. musk is widely regarded by analysts and investors as the creative engine behind tesla and he has helped the company become one of the most valuable american carmakers. but tesla has lurched from crisis to crisis over the past year and has since scrambled to contain the fallout from mr. musks tweet.the company whose shares have been hit hard since the s.e.c. filed the lawsuit did not immediately comment on the settlement. on friday its stock dropped almost 14 percent.the terms of the settlement are slightly tougher than those that two people briefed on the talks said mr. musk had rejected on thursday which called for a twoyear bar on serving as chairman and a $10 million fine.tesla which is also settling with the s.e.c. will pay a $20 million penalty. the company was not charged with any fraud.in addition the company will add two independent directors and take steps to monitor mr. musks communications with investors. it will also create a permanent committee of independent directors to monitor disclosures and potential conflicts of interest.jay clayton the s.e.c. chairman said the settlement with mr. musk and tesla sent a message that when companies and corporate insiders make statements they must act responsibly including endeavoring to ensure the statements are not false or misleading.in settling mr. musk neither admitted nor denied misleading investors under the civil fraud charge which means he cannot later say he did nothing wrong.the settlement with the s.e.c. faulted tesla for failing to make sure that information important to investors was disclosed in a proper and timely manner.serial entrepreneur elon musk wants to fundamentally change the way we live. but his path to success has been characterized by both great accomplishments and flirtations with failure.mr. musk had a good reason to reopen the settlement talks the s.e.c. in suing him had sought to bar him permanently from serving as a top executive or officer of tesla or any other public company. under the deal reached on saturday he will not only remain as chief executive but will also stay on as a board member just not as chairman.the total package of remedies and relief announced today are specifically designed to address the misconduct at issue by strengthening teslas corporate governance and oversight in order to protect investors said stephanie avakian codirector of the s.e.c.s enforcement division.mr. musk according to people familiar with the negotiations had been concerned ...

# %% [markdown]
# #### The default encoding of python is set to utf-8.

# %%
import sys  

reload(sys)  
sys.setdefaultencoding('utf8')

# %%
# In this step the words are tokenized and stop words are removed

stopWords = set(stopwords.words("english"))

words = word_tokenize(cleaned_text[0])

# %%
without_stop_words = {}

for word in words :
    word = word.lower()
    
    if word in stopWords:
        continue
    if word in without_stop_words:
        without_stop_words[word] += 1
    else :
        without_stop_words[word] = 1

# %% [markdown]
# ### The without stop words dictionary contains the different individual words/characters present in the document as the keys and the value corresponding to each key is its frequency of occurance. The Frequency of each word is normalised [0,1].

# %%
without_stop_words
# Out:
# {'$': 5,
#  '.': 35,
#  '10': 1,
#  '14': 1,
#  '20': 3,
#  '3': 1,
#  '420': 1,
#  '7': 1,
#  'ability': 1,
#  'accomplishments': 1,
#  'according': 2,
#  'account': 1,
#  'act': 1,
#  'action': 1,
#  'add': 1,
#  'addition': 1,
#  'address': 1,
#  'admit': 1,
#  'admitted': 1,
#  'affect': 1,
#  'agency.it': 1,
#  'ago': 1,
#  'agreed': 1,
#  'agreeing': 1,
#  'allow': 1,
#  'almost': 1,
#  'along': 1,
#  'also': 3,
#  'american': 1,
#  'amount': 1,
#  'analysts': 1,
#  'announced': 3,
#  'another': 1,
#  'aside': 1,
#  'asked': 1,
#  'attacks': 1,
#  'audacious': 1,
#  'aug.': 1,
#  'authorized': 2,
#  'avakian': 1,
#  'away': 1,
#  'backed': 1,
#  'bar': 2,
#  'battle': 1,
#  'battles': 1,
#  'became': 1,
#  'become': 2,
#  'began': 1,
#  'behind': 1,
#  'bets': 1,
#  'big': 1,
#  'billionaire': 1,
#  'board': 2,
#  'boring': 1,
#  'bought': 1,
#  'briefed': 2,
#  'buying': 1,
#  'buyout': 1,
#  'called': 1,
#  'carmakers': 1,
#  'caused': 1,
#  'chairman': 4,
#  'chairman.the': 1,
#  'change': 1,
#  'changed': 1,
#  'characterized': 1,
#  'charge': 2,
#  'charged': 1,
#  'charges': 1,
#  'chief': 2,
#  'civil': 2,
#  'claims': 1,
#  'clayton': 1,
#  'clear': 1,
#  'clears': 1,
#  'codirector': 1,
#  'cofounded': 1,
#  'comment': 1,
#  'commission': 1,
#  'committee': 1,
#  'communications': 1,
#  'companies': 3,
#  'company': 14,
#  'companys': 1,
#  'concerned': 2,
#  'concerns': 1,
#  'conflicts': 1,
#  'considering': 1,
#  'contain': 1,
#  'continued': 1,
#  'continuing': 1,
#  'conversations': 1,
#  'corporate': 2,
#  'could': 3,
#  'couple': 1,
#  'court': 2,
#  'create': 1,
#  'creative': 1,
#  'crisis': 2,
#  'criticism': 1,
#  'critics': 1,
#  'cuban': 1,
#  'days': 3,
#  'deal': 8,
#  'debt': 1,
#  'decide': 1,
#  'denied': 1,
#  'deny': 1,
#  'designed': 1,
#  'difficult': 1,
#  'directors': 2,
#  'disavow': 1,
#  'disclosed': 1,
#  'disclosures': 1,
#  'division.mr': 1,
#  'done': 1,
#  'done.the': 1,
#  'dropped': 1,
#  'electriccar': 1,
#  'elon': 2,
#  'endeavoring': 1,
#  'enforcement': 2,
#  'engine': 1,
#  'ensure': 1,
#  'entrepreneur': 2,
#  'even': 1,
#  'evening': 1,
#  'events': 1,
#  'eventually': 2,
#  'exchange': 1,
#  'executive': 3,
#  'experts': 1,
#  'failing': 1,
#  'failure.mr': 1,
#  'fallout': 1,
#  'false': 1,
#  'familiar': 6,
#  'faulted': 1,
#  'federal': 2,
#  'fight': 1,
#  'filed': 2,
#  'filing': 1,
#  'fine.tesla': 1,
#  'fine.the': 1,
#  'flirtations': 1,
#  'focused': 1,
#  'followed': 1,
#  'force': 1,
#  'forward': 1,
#  'fraud': 3,
#  'fraud.in': 1,
#  'friday': 3,
#  'friends': 1,
#  'fundamentally': 1,
#  'funding': 1,
#  'gave': 1,
#  'get': 1,
#  'goals': 2,
#  'gone': 1,
#  'good': 1,
#  'governance': 1,
#  'granted': 1,
#  'great': 1,
#  'hard': 1,
#  'headache': 1,
#  'held': 1,
#  'helped': 1,
#  'hit': 1,
#  'immediate': 1,
#  'immediately': 1,
#  'important': 1,
#  'including': 2,
#  'independent': 2,
#  'information': 2,
#  'initial': 1,
#  'insiders': 1,
#  'instrumental': 1,
#  'interest.jay': 1,
#  'investors': 11,
#  'issue': 1,
#  'jeopardized': 1,
#  'last': 1,
#  'later': 3,
#  'lawsuit': 1,
#  'lawyers': 5,
#  'legal': 1,
#  'like': 1,
#  'live': 1,
#  'look': 1,
#  'lurched': 1,
#  'make': 2,
#  'making': 1,
#  'manhattan.the': 1,
#  'manner.serial': 1,
#  'mark': 1,
#  'markets.but': 1,
#  'matches': 1,
#  'matter': 3,
#  'means': 1,
#  'meantime': 1,
#  'media': 1,
#  'meet': 1,
#  'member': 1,
#  'message': 1,
#  'might': 1,
#  'million': 4,
#  'mind': 1,
#  'misconduct': 1,
#  'misleading': 2,
#  'misleading.in': 1,
#  'model': 1,
#  'money': 1,
#  'monitor': 2,
#  'month': 1,
#  'moved': 2,
#  'moving': 1,
#  'mr.': 20,
#  'much': 1,
#  'musk': 23,
#  'musk.his': 1,
#  'musks': 2,
#  'must': 2,
#  'negotiations': 1,
#  'negotiations.the': 2,
#  'neither': 1,
#  'nothing': 2,
#  'notice': 1,
#  'officer': 1,
#  'official': 1,
#  'one': 3,
#  'order': 1,
#  'others': 1,
#  'oversight': 1,
#  'package': 1,
#  'part': 1,
#  'parties': 2,
#  'party': 1,
#  'past': 3,
#  'path': 1,
#  'pay': 3,
#  'penalty': 2,
#  'people': 4,
#  'percent.the': 1,
#  'permanent': 1,
#  'permanently': 1,
#  'person': 3,
#  'placements': 1,
#  'plan': 1,
#  'planning': 1,
#  'post': 1,
#  'potential': 1,
#  'pressure': 1,
#  'private': 2,
#  'problems': 1,
#  'production': 2,
#  'proper': 1,
#  'protect': 1,
#  'public': 1,
#  'publicly': 1,
#  'publicly.once': 1,
#  'quickly': 1,
#  'quickly.people': 1,
#  'raise': 1,
#  'raised': 1,
#  'reached': 3,
#  'reacted': 1,
#  'reason': 1,
#  'recently': 1,
#  'regarded': 1,
#  'regulators': 2,
#  'rejected': 2,
#  'relief': 1,
#  'remain': 2,
#  'remain.the': 1,
#  'remedies': 1,
#  'reopen': 2,
#  'replace': 1,
#  'requires': 1,
#  'resolve': 1,
#  'responsibly': 1,
#  'runs': 1,
#  's.e.c': 16,
#  's.e.c.s': 1,
#  'said': 13,
#  'said.a': 1,
#  'said.in': 1,
#  'said.negotiations': 1,
#  'saturday': 4,
#  'say': 1,
#  'scrambled': 1,
#  'secured': 1,
#  'securing': 1,
#  'securities': 2,
#  'sedan.mr': 1,
#  'seeking': 1,
#  'selfinflicted': 1,
#  'send': 1,
#  'sense': 1,
#  'sent': 1,
#  'series': 1,
#  'served': 1,
#  'serving': 2,
#  'settlement': 15,
#  'settlement.after': 1,
#  'settling': 4,
#  'share.the': 1,
#  'shares': 2,
#  'shortsellers': 1,
#  'since': 2,
#  'situation': 2,
#  'slightly': 1,
#  'socalled': 2,
#  'social': 1,
#  'something': 1,
#  'sought': 1,
#  'spacex': 1,
#  'speak': 2,
#  'specifically': 1,
#  'spokesman': 2,
#  'statements': 2,
#  'stay': 1,
#  'step': 2,
#  'stephanie': 1,
#  'steps': 1,
#  'stock': 3,
#  'strengthening': 1,
#  'struggling': 1,
#  'subpoena': 1,
#  'success': 1,
#  'sued': 2,
#  'suing': 1,
#  'suits': 1,
#  'sure': 1,
#  'surge': 1,
#  'take': 2,
#  'taking': 1,
#  'talk': 2,
#  'talks': 4,
#  'tell': 1,
#  'terms': 2,
#  'tesla': 15,
#  'teslas': 3,
#  'testimony': 1,
#  'that.in': 1,
#  'them.waivers': 1,
#  'thought': 1,
#  'three': 1,
#  'thursday': 2,
#  'thursday.mr': 1,
#  'time': 1,
#  'timely': 1,
#  'today': 1,
#  'top': 1,
#  'total': 1,
#  'tougher': 1,
#  'toward': 1,
#  'tweet': 2,
#  'tweet.the': 1,
#  'twitter': 1,
#  'two': 3,
#  'twoyear': 1,
#  'uncommon': 1,
#  'valuable': 1,
#  'wait': 1,
#  'waivers': 1,
#  'wants': 1,
#  'way': 1,
#  'wednesday': 1,
#  'week': 1,
#  'whether': 2,
#  'whipsaw': 1,
#  'whose': 1,
#  'widely': 1,
#  'worked': 1,
#  'would': 2,
#  'wounds': 1,
#  'wrong': 1,
#  'wrong.the': 1,
#  'year': 1,
#  'years': 1}

# %%
# Here I have considered minimum count as 0

maximum_count = float(max(without_stop_words.values()))

for without_stop_word in without_stop_words.keys() :
    without_stop_words[without_stop_word] = without_stop_words[without_stop_word] / maximum_count

# %% [markdown]
# #### Step 2 :
#
# Identify individual sentences from the document. With the help of the words frequency distribution table obtained from Step 2, assign values to each word accordingly for each sentence, hence obtaining sentence score for each sentence. Identify sentences which have a scores more than a particular threshold value.

# %%
sentences = sent_tokenize(cleaned_text[0])
sentence_value = {} 

for sentence in sentences :
    for w in word_tokenize(sentence) :
        if w in without_stop_words.keys():
            if sentence not in sentence_value.keys():
                sentence_value[sentence] = without_stop_words[w]
            else:
                sentence_value[sentence] += without_stop_words[w]

# %%
sentence_value
# Out:
# {'according to a person familiar with the negotiations.the whipsaw events of the past few days followed a series of selfinflicted wounds by mr. musk.his tweet about taking his company private along with attacks on critics on social media raised concerns with investors about whether mr. musk has become too focused on criticism from socalled shortsellers who had been making bets against him and tesla.': 5.342857142857141,
#  'and now with mr. musk agreeing to step down as chairman teslas board must decide who should replace him.': 2.6857142857142855,
#  'and they gave him a sense of how difficult it is to fight one of these suits even if he eventually won said people familiar with the negotiations.the parties worked much of friday and saturday to get a deal done.the settlement clears a big headache for tesla but other problems remain.the s.e.c.': 4.085714285714285,
#  'announced the deal two days after it sued mr. musk in federal court for misleading investors over his post on twitter last month that he had funding secured for a buyout of the electriccar company at $420 a share.the deal with the s.e.c.': 4.7714285714285705,
#  'but his path to success has been characterized by both great accomplishments and flirtations with failure.mr.': 1.2,
#  'but tesla has lurched from crisis to crisis over the past year and has since scrambled to contain the fallout from mr. musks tweet.the company whose shares have been hit hard since the s.e.c.': 3.5428571428571427,
#  'but the settlement on saturday requires him to do that.in a socalled admit nor deny settlement a settling party cannot later disavow the terms of the settlement.after mr. musk was said to have rejected the deal on thursday his lawyers asked the s.e.c.': 5.057142857142856,
#  'by their account all the parties thought a deal had been reached by wednesday evening and the plan was for a settlement with mr. musk and tesla to be announced on thursday.mr.': 3.714285714285714,
#  'chairman said the settlement with mr. musk and tesla sent a message that when companies and corporate insiders make statements they must act responsibly including endeavoring to ensure the statements are not false or misleading.in settling mr. musk neither admitted nor denied misleading investors under the civil fraud charge which means he cannot later say he did nothing wrong.the settlement with the s.e.c.': 7.3714285714285674,
#  'during that time one of teslas lawyers became instrumental in securing a deal with the s.e.c.': 2.1142857142857143,
#  'elon musk under pressure from his lawyers and investors of tesla the company he cofounded reached a deal with the securities and exchange commission on saturday to resolve securities fraud charges.': 3.7999999999999994,
#  'faulted tesla for failing to make sure that information important to investors was disclosed in a proper and timely manner.serial entrepreneur elon musk wants to fundamentally change the way we live.': 2.999999999999999,
#  'filed the lawsuit did not immediately comment on the settlement.': 1.5714285714285714,
#  'had granted waivers to all of those companies so his settlement would not be held against them.waivers in such a situation are not uncommon legal experts have said.a tesla spokesman said that mr. musk a billionaire would be buying $20 million in tesla stock.': 4.914285714285714,
#  'in suing him had sought to bar him permanently from serving as a top executive or officer of tesla or any other public company.': 2.2,
#  'is continuing to look into the companys past claims about its production goals.': 1.3142857142857143,
#  'it will also create a permanent committee of independent directors to monitor disclosures and potential conflicts of interest.jay clayton the s.e.c.': 1.9428571428571428,
#  'musk according to people familiar with the negotiations had been concerned about whether settling a civil fraud charge might affect the ability of tesla and the other companies he runs including spacex and the boring company to raise money from investors in private placements and the debt markets.but a tesla spokesman said the s.e.c.': 5.428571428571427,
#  'musk had a good reason to reopen the settlement talks the s.e.c.': 2.7714285714285714,
#  'musk is widely regarded by analysts and investors as the creative engine behind tesla and he has helped the company become one of the most valuable american carmakers.': 3.2285714285714278,
#  'musk was said to have backed away from a settlement in part because he was concerned that he could not later tell investors that he had not done nothing wrong.': 3.2285714285714278,
#  'on friday its stock dropped almost 14 percent.the terms of the settlement are slightly tougher than those that two people briefed on the talks said mr. musk had rejected on thursday which called for a twoyear bar on serving as chairman and a $10 million fine.tesla which is also settling with the s.e.c.': 5.171428571428571,
#  'on friday.': 1.0857142857142856,
#  'reacted quickly after the aug. 7 tweet which caused an immediate surge in tesla shares.': 1.7428571428571429,
#  'regulators served a subpoena on the company seeking information and moved to take testimony from mr. musk and others at the company people familiar with the matter said.negotiations toward an initial settlement began about a week ago after the s.e.c.': 4.828571428571427,
#  'said it was planning to send an official notice to mr. musk and tesla that it was considering filing an enforcement action those briefed on the talks said.': 3.828571428571428,
#  'sued mr. musk his lawyers continued to talk to him about moving forward with a settlement and eventually he agreed this person said.in the meantime mr. musk had conversations with investors and friends like mark cuban an entrepreneur who has had his own battles with the s.e.c.': 5.4571428571428555,
#  'the amount of stock being bought by mr. musk matches the penalty the company has to pay under the settlement which was filed in federal court in manhattan.the s.e.c.': 4.0285714285714285,
#  'the company has recently been struggling to meet audacious production goals for its model 3 sedan.mr.': 1.7142857142857144,
#  'the company was not charged with any fraud.in addition the company will add two independent directors and take steps to monitor mr. musks communications with investors.': 3.2285714285714286,
#  'the settlement will force mr. musk to step aside as chairman for three years and pay a $20 million fine.the s.e.c.': 3.8571428571428568,
#  'to wait a couple of days so they could talk him into it but the regulators said no said another person familiar with the matter but not authorized to speak publicly.once the s.e.c.': 3.057142857142857,
#  'under the deal reached on saturday he will not only remain as chief executive but will also stay on as a board member just not as chairman.the total package of remedies and relief announced today are specifically designed to address the misconduct at issue by strengthening teslas corporate governance and oversight in order to protect investors said stephanie avakian codirector of the s.e.c.s enforcement division.mr.': 3.399999999999998,
#  'will allow him to remain as chief executive something he could have jeopardized if he had gone to battle with the agency.it is not clear why mr. musk changed his mind so quickly.people familiar with the situation who were not authorized to speak publicly on the matter said lawyers for mr. musk and the company moved to reopen the talks with the s.e.c.': 6.0857142857142845,
#  'will pay a $20 million penalty.': 1.4857142857142858}

# %%
# I have considered a threshold of 4.0

summarised = {}   
         
for x in sentences :
    if sentence_value[x] >= 4.0 :
        summarised[x] = sentence_value[x]
    else :
        pass

# %%
summarised.keys()
# Out:
# ['the amount of stock being bought by mr. musk matches the penalty the company has to pay under the settlement which was filed in federal court in manhattan.the s.e.c.',
#  'and they gave him a sense of how difficult it is to fight one of these suits even if he eventually won said people familiar with the negotiations.the parties worked much of friday and saturday to get a deal done.the settlement clears a big headache for tesla but other problems remain.the s.e.c.',
#  'but the settlement on saturday requires him to do that.in a socalled admit nor deny settlement a settling party cannot later disavow the terms of the settlement.after mr. musk was said to have rejected the deal on thursday his lawyers asked the s.e.c.',
#  'had granted waivers to all of those companies so his settlement would not be held against them.waivers in such a situation are not uncommon legal experts have said.a tesla spokesman said that mr. musk a billionaire would be buying $20 million in tesla stock.',
#  'on friday its stock dropped almost 14 percent.the terms of the settlement are slightly tougher than those that two people briefed on the talks said mr. musk had rejected on thursday which called for a twoyear bar on serving as chairman and a $10 million fine.tesla which is also settling with the s.e.c.',
#  'regulators served a subpoena on the company seeking information and moved to take testimony from mr. musk and others at the company people familiar with the matter said.negotiations toward an initial settlement began about a week ago after the s.e.c.',
#  'chairman said the settlement with mr. musk and tesla sent a message that when companies and corporate insiders make statements they must act responsibly including endeavoring to ensure the statements are not false or misleading.in settling mr. musk neither admitted nor denied misleading investors under the civil fraud charge which means he cannot later say he did nothing wrong.the settlement with the s.e.c.',
#  'sued mr. musk his lawyers continued to talk to him about moving forward with a settlement and eventually he agreed this person said.in the meantime mr. musk had conversations with investors and friends like mark cuban an entrepreneur who has had his own battles with the s.e.c.',
#  'will allow him to remain as chief executive something he could have jeopardized if he had gone to battle with the agency.it is not clear why mr. musk changed his mind so quickly.people familiar with the situation who were not authorized to speak publicly on the matter said lawyers for mr. musk and the company moved to reopen the talks with the s.e.c.',
#  'musk according to people familiar with the negotiations had been concerned about whether settling a civil fraud charge might affect the ability of tesla and the other companies he runs including spacex and the boring company to raise money from investors in private placements and the debt markets.but a tesla spokesman said the s.e.c.',
#  'according to a person familiar with the negotiations.the whipsaw events of the past few days followed a series of selfinflicted wounds by mr. musk.his tweet about taking his company private along with attacks on critics on social media raised concerns with investors about whether mr. musk has become too focused on criticism from socalled shortsellers who had been making bets against him and tesla.',
#  'announced the deal two days after it sued mr. musk in federal court for misleading investors over his post on twitter last month that he had funding secured for a buyout of the electriccar company at $420 a share.the deal with the s.e.c.']

# %%
tagged ={}

pattern = 'NP: {<DT>?<JJ>*<NN>}'

m = nltk.RegexpParser(pattern)

       
for summ in summarised.keys() :
    tagged[summ] = pos_tag(word_tokenize(summ))
    tagged[summ] = m.parse(tagged[summ])
    tagged[summ] = tree2conlltags(tagged[summ])

# %%
tagged
# Out:
# {'according to a person familiar with the negotiations.the whipsaw events of the past few days followed a series of selfinflicted wounds by mr. musk.his tweet about taking his company private along with attacks on critics on social media raised concerns with investors about whether mr. musk has become too focused on criticism from socalled shortsellers who had been making bets against him and tesla.': [('according',
#    'VBG',
#    u'O'),
#   ('to', 'TO', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('person', 'NN', u'I-NP'),
#   ('familiar', 'JJ', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'O'),
#   ('negotiations.the', 'JJ', u'O'),
#   ('whipsaw', 'JJ', u'O'),
#   ('events', 'NNS', u'O'),
#   ('of', 'IN', u'O'),
#   ('the', 'DT', u'O'),
#   ('past', 'JJ', u'O'),
#   ('few', 'JJ', u'O'),
#   ('days', 'NNS', u'O'),
#   ('followed', 'VBD', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('series', 'NN', u'I-NP'),
#   ('of', 'IN', u'O'),
#   ('selfinflicted', 'JJ', u'O'),
#   ('wounds', 'NNS', u'O'),
#   ('by', 'IN', u'O'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk.his', 'NNP', u'O'),
#   ('tweet', 'VBZ', u'O'),
#   ('about', 'IN', u'O'),
#   ('taking', 'VBG', u'O'),
#   ('his', 'PRP$', u'O'),
#   ('company', 'NN', u'B-NP'),
#   ('private', 'JJ', u'O'),
#   ('along', 'IN', u'O'),
#   ('with', 'IN', u'O'),
#   ('attacks', 'NNS', u'O'),
#   ('on', 'IN', u'O'),
#   ('critics', 'NNS', u'O'),
#   ('on', 'IN', u'O'),
#   ('social', 'JJ', u'O'),
#   ('media', 'NNS', u'O'),
#   ('raised', 'VBN', u'O'),
#   ('concerns', 'NNS', u'O'),
#   ('with', 'IN', u'O'),
#   ('investors', 'NNS', u'O'),
#   ('about', 'IN', u'O'),
#   ('whether', 'IN', u'O'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'NNP', u'O'),
#   ('has', 'VBZ', u'O'),
#   ('become', 'VBN', u'O'),
#   ('too', 'RB', u'O'),
#   ('focused', 'JJ', u'O'),
#   ('on', 'IN', u'O'),
#   ('criticism', 'NN', u'B-NP'),
#   ('from', 'IN', u'O'),
#   ('socalled', 'VBN', u'O'),
#   ('shortsellers', 'NNS', u'O'),
#   ('who', 'WP', u'O'),
#   ('had', 'VBD', u'O'),
#   ('been', 'VBN', u'O'),
#   ('making', 'VBG', u'O'),
#   ('bets', 'NNS', u'O'),
#   ('against', 'IN', u'O'),
#   ('him', 'PRP', u'O'),
#   ('and', 'CC', u'O'),
#   ('tesla', 'NN', u'B-NP'),
#   ('.', '.', u'O')],
#  'and they gave him a sense of how difficult it is to fight one of these suits even if he eventually won said people familiar with the negotiations.the parties worked much of friday and saturday to get a deal done.the settlement clears a big headache for tesla but other problems remain.the s.e.c.': [('and',
#    'CC',
#    u'O'),
#   ('they', 'PRP', u'O'),
#   ('gave', 'VBD', u'O'),
#   ('him', 'PRP', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('sense', 'NN', u'I-NP'),
#   ('of', 'IN', u'O'),
#   ('how', 'WRB', u'O'),
#   ('difficult', 'JJ', u'O'),
#   ('it', 'PRP', u'O'),
#   ('is', 'VBZ', u'O'),
#   ('to', 'TO', u'O'),
#   ('fight', 'VB', u'O'),
#   ('one', 'CD', u'O'),
#   ('of', 'IN', u'O'),
#   ('these', 'DT', u'O'),
#   ('suits', 'NNS', u'O'),
#   ('even', 'RB', u'O'),
#   ('if', 'IN', u'O'),
#   ('he', 'PRP', u'O'),
#   ('eventually', 'RB', u'O'),
#   ('won', 'VBD', u'O'),
#   ('said', 'VBD', u'O'),
#   ('people', 'NNS', u'O'),
#   ('familiar', 'JJ', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'O'),
#   ('negotiations.the', 'JJ', u'O'),
#   ('parties', 'NNS', u'O'),
#   ('worked', 'VBD', u'O'),
#   ('much', 'JJ', u'O'),
#   ('of', 'IN', u'O'),
#   ('friday', 'NN', u'B-NP'),
#   ('and', 'CC', u'O'),
#   ('saturday', 'NN', u'B-NP'),
#   ('to', 'TO', u'O'),
#   ('get', 'VB', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('deal', 'NN', u'I-NP'),
#   ('done.the', 'NN', u'B-NP'),
#   ('settlement', 'NN', u'B-NP'),
#   ('clears', 'VBZ', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('big', 'JJ', u'I-NP'),
#   ('headache', 'NN', u'I-NP'),
#   ('for', 'IN', u'O'),
#   ('tesla', 'NN', u'B-NP'),
#   ('but', 'CC', u'O'),
#   ('other', 'JJ', u'O'),
#   ('problems', 'NNS', u'O'),
#   ('remain.the', 'VBP', u'O'),
#   ('s.e.c', 'NN', u'B-NP'),
#   ('.', '.', u'O')],
#  'announced the deal two days after it sued mr. musk in federal court for misleading investors over his post on twitter last month that he had funding secured for a buyout of the electriccar company at $420 a share.the deal with the s.e.c.': [('announced',
#    'VBD',
#    u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('deal', 'NN', u'I-NP'),
#   ('two', 'CD', u'O'),
#   ('days', 'NNS', u'O'),
#   ('after', 'IN', u'O'),
#   ('it', 'PRP', u'O'),
#   ('sued', 'VBD', u'O'),
#   ('mr.', 'JJ', u'O'),
#   ('musk', 'NNP', u'O'),
#   ('in', 'IN', u'O'),
#   ('federal', 'JJ', u'B-NP'),
#   ('court', 'NN', u'I-NP'),
#   ('for', 'IN', u'O'),
#   ('misleading', 'VBG', u'O'),
#   ('investors', 'NNS', u'O'),
#   ('over', 'IN', u'O'),
#   ('his', 'PRP$', u'O'),
#   ('post', 'NN', u'B-NP'),
#   ('on', 'IN', u'O'),
#   ('twitter', 'NN', u'B-NP'),
#   ('last', 'JJ', u'B-NP'),
#   ('month', 'NN', u'I-NP'),
#   ('that', 'IN', u'O'),
#   ('he', 'PRP', u'O'),
#   ('had', 'VBD', u'O'),
#   ('funding', 'NN', u'B-NP'),
#   ('secured', 'VBN', u'O'),
#   ('for', 'IN', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('buyout', 'NN', u'I-NP'),
#   ('of', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('electriccar', 'NN', u'I-NP'),
#   ('company', 'NN', u'B-NP'),
#   ('at', 'IN', u'O'),
#   ('$', '$', u'O'),
#   ('420', 'CD', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('share.the', 'NN', u'I-NP'),
#   ('deal', 'NN', u'B-NP'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'but the settlement on saturday requires him to do that.in a socalled admit nor deny settlement a settling party cannot later disavow the terms of the settlement.after mr. musk was said to have rejected the deal on thursday his lawyers asked the s.e.c.': [('but',
#    'CC',
#    u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('settlement', 'NN', u'I-NP'),
#   ('on', 'IN', u'O'),
#   ('saturday', 'JJ', u'O'),
#   ('requires', 'VBZ', u'O'),
#   ('him', 'PRP', u'O'),
#   ('to', 'TO', u'O'),
#   ('do', 'VB', u'O'),
#   ('that.in', 'VB', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('socalled', 'JJ', u'I-NP'),
#   ('admit', 'NN', u'I-NP'),
#   ('nor', 'CC', u'O'),
#   ('deny', 'JJ', u'B-NP'),
#   ('settlement', 'NN', u'I-NP'),
#   ('a', 'DT', u'O'),
#   ('settling', 'VBG', u'O'),
#   ('party', 'NN', u'B-NP'),
#   ('can', 'MD', u'O'),
#   ('not', 'RB', u'O'),
#   ('later', 'RB', u'O'),
#   ('disavow', 'VB', u'O'),
#   ('the', 'DT', u'O'),
#   ('terms', 'NNS', u'O'),
#   ('of', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('settlement.after', 'NN', u'I-NP'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'NNP', u'O'),
#   ('was', 'VBD', u'O'),
#   ('said', 'VBD', u'O'),
#   ('to', 'TO', u'O'),
#   ('have', 'VB', u'O'),
#   ('rejected', 'VBN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('deal', 'NN', u'I-NP'),
#   ('on', 'IN', u'O'),
#   ('thursday', 'NN', u'B-NP'),
#   ('his', 'PRP$', u'O'),
#   ('lawyers', 'NNS', u'O'),
#   ('asked', 'VBD', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'chairman said the settlement with mr. musk and tesla sent a message that when companies and corporate insiders make statements they must act responsibly including endeavoring to ensure the statements are not false or misleading.in settling mr. musk neither admitted nor denied misleading investors under the civil fraud charge which means he cannot later say he did nothing wrong.the settlement with the s.e.c.': [('chairman',
#    'NN',
#    u'B-NP'),
#   ('said', 'VBD', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('settlement', 'NN', u'I-NP'),
#   ('with', 'IN', u'O'),
#   ('mr.', 'JJ', u'B-NP'),
#   ('musk', 'NN', u'I-NP'),
#   ('and', 'CC', u'O'),
#   ('tesla', 'NN', u'B-NP'),
#   ('sent', 'VBD', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('message', 'NN', u'I-NP'),
#   ('that', 'IN', u'O'),
#   ('when', 'WRB', u'O'),
#   ('companies', 'NNS', u'O'),
#   ('and', 'CC', u'O'),
#   ('corporate', 'JJ', u'O'),
#   ('insiders', 'NNS', u'O'),
#   ('make', 'VBP', u'O'),
#   ('statements', 'NNS', u'O'),
#   ('they', 'PRP', u'O'),
#   ('must', 'MD', u'O'),
#   ('act', 'VB', u'O'),
#   ('responsibly', 'RB', u'O'),
#   ('including', 'VBG', u'O'),
#   ('endeavoring', 'VBG', u'O'),
#   ('to', 'TO', u'O'),
#   ('ensure', 'VB', u'O'),
#   ('the', 'DT', u'O'),
#   ('statements', 'NNS', u'O'),
#   ('are', 'VBP', u'O'),
#   ('not', 'RB', u'O'),
#   ('false', 'JJ', u'O'),
#   ('or', 'CC', u'O'),
#   ('misleading.in', 'JJ', u'O'),
#   ('settling', 'VBG', u'O'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'NNP', u'O'),
#   ('neither', 'RB', u'O'),
#   ('admitted', 'VBD', u'O'),
#   ('nor', 'CC', u'O'),
#   ('denied', 'VBD', u'O'),
#   ('misleading', 'VBG', u'O'),
#   ('investors', 'NNS', u'O'),
#   ('under', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('civil', 'JJ', u'I-NP'),
#   ('fraud', 'NN', u'I-NP'),
#   ('charge', 'NN', u'B-NP'),
#   ('which', 'WDT', u'O'),
#   ('means', 'VBZ', u'O'),
#   ('he', 'PRP', u'O'),
#   ('can', 'MD', u'O'),
#   ('not', 'RB', u'O'),
#   ('later', 'RB', u'O'),
#   ('say', 'VB', u'O'),
#   ('he', 'PRP', u'O'),
#   ('did', 'VBD', u'O'),
#   ('nothing', 'NN', u'B-NP'),
#   ('wrong.the', 'NN', u'B-NP'),
#   ('settlement', 'NN', u'B-NP'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'had granted waivers to all of those companies so his settlement would not be held against them.waivers in such a situation are not uncommon legal experts have said.a tesla spokesman said that mr. musk a billionaire would be buying $20 million in tesla stock.': [('had',
#    'VBD',
#    u'O'),
#   ('granted', 'VBN', u'O'),
#   ('waivers', 'NNS', u'O'),
#   ('to', 'TO', u'O'),
#   ('all', 'DT', u'O'),
#   ('of', 'IN', u'O'),
#   ('those', 'DT', u'O'),
#   ('companies', 'NNS', u'O'),
#   ('so', 'IN', u'O'),
#   ('his', 'PRP$', u'O'),
#   ('settlement', 'NN', u'B-NP'),
#   ('would', 'MD', u'O'),
#   ('not', 'RB', u'O'),
#   ('be', 'VB', u'O'),
#   ('held', 'VBN', u'O'),
#   ('against', 'IN', u'O'),
#   ('them.waivers', 'NNS', u'O'),
#   ('in', 'IN', u'O'),
#   ('such', 'JJ', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('situation', 'NN', u'I-NP'),
#   ('are', 'VBP', u'O'),
#   ('not', 'RB', u'O'),
#   ('uncommon', 'JJ', u'O'),
#   ('legal', 'JJ', u'O'),
#   ('experts', 'NNS', u'O'),
#   ('have', 'VBP', u'O'),
#   ('said.a', 'VBN', u'O'),
#   ('tesla', 'NN', u'B-NP'),
#   ('spokesman', 'NN', u'B-NP'),
#   ('said', 'VBD', u'O'),
#   ('that', 'IN', u'O'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'VBP', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('billionaire', 'NN', u'I-NP'),
#   ('would', 'MD', u'O'),
#   ('be', 'VB', u'O'),
#   ('buying', 'VBG', u'O'),
#   ('$', '$', u'O'),
#   ('20', 'CD', u'O'),
#   ('million', 'CD', u'O'),
#   ('in', 'IN', u'O'),
#   ('tesla', 'JJ', u'B-NP'),
#   ('stock', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'musk according to people familiar with the negotiations had been concerned about whether settling a civil fraud charge might affect the ability of tesla and the other companies he runs including spacex and the boring company to raise money from investors in private placements and the debt markets.but a tesla spokesman said the s.e.c.': [('musk',
#    'NN',
#    u'B-NP'),
#   ('according', 'VBG', u'O'),
#   ('to', 'TO', u'O'),
#   ('people', 'NNS', u'O'),
#   ('familiar', 'JJ', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'O'),
#   ('negotiations', 'NNS', u'O'),
#   ('had', 'VBD', u'O'),
#   ('been', 'VBN', u'O'),
#   ('concerned', 'VBN', u'O'),
#   ('about', 'IN', u'O'),
#   ('whether', 'IN', u'O'),
#   ('settling', 'VBG', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('civil', 'JJ', u'I-NP'),
#   ('fraud', 'NN', u'I-NP'),
#   ('charge', 'NN', u'B-NP'),
#   ('might', 'MD', u'O'),
#   ('affect', 'VB', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('ability', 'NN', u'I-NP'),
#   ('of', 'IN', u'O'),
#   ('tesla', 'NN', u'B-NP'),
#   ('and', 'CC', u'O'),
#   ('the', 'DT', u'O'),
#   ('other', 'JJ', u'O'),
#   ('companies', 'NNS', u'O'),
#   ('he', 'PRP', u'O'),
#   ('runs', 'VBZ', u'O'),
#   ('including', 'VBG', u'O'),
#   ('spacex', 'NN', u'B-NP'),
#   ('and', 'CC', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('boring', 'JJ', u'I-NP'),
#   ('company', 'NN', u'I-NP'),
#   ('to', 'TO', u'O'),
#   ('raise', 'VB', u'O'),
#   ('money', 'NN', u'B-NP'),
#   ('from', 'IN', u'O'),
#   ('investors', 'NNS', u'O'),
#   ('in', 'IN', u'O'),
#   ('private', 'JJ', u'O'),
#   ('placements', 'NNS', u'O'),
#   ('and', 'CC', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('debt', 'NN', u'I-NP'),
#   ('markets.but', 'NN', u'B-NP'),
#   ('a', 'DT', u'B-NP'),
#   ('tesla', 'NN', u'I-NP'),
#   ('spokesman', 'NN', u'B-NP'),
#   ('said', 'VBD', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'on friday its stock dropped almost 14 percent.the terms of the settlement are slightly tougher than those that two people briefed on the talks said mr. musk had rejected on thursday which called for a twoyear bar on serving as chairman and a $10 million fine.tesla which is also settling with the s.e.c.': [('on',
#    'IN',
#    u'O'),
#   ('friday', 'NN', u'B-NP'),
#   ('its', 'PRP$', u'O'),
#   ('stock', 'NN', u'B-NP'),
#   ('dropped', 'VBD', u'O'),
#   ('almost', 'RB', u'O'),
#   ('14', 'CD', u'O'),
#   ('percent.the', 'JJ', u'O'),
#   ('terms', 'NNS', u'O'),
#   ('of', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('settlement', 'NN', u'I-NP'),
#   ('are', 'VBP', u'O'),
#   ('slightly', 'RB', u'O'),
#   ('tougher', 'JJR', u'O'),
#   ('than', 'IN', u'O'),
#   ('those', 'DT', u'O'),
#   ('that', 'WDT', u'O'),
#   ('two', 'CD', u'O'),
#   ('people', 'NNS', u'O'),
#   ('briefed', 'VBP', u'O'),
#   ('on', 'IN', u'O'),
#   ('the', 'DT', u'O'),
#   ('talks', 'NNS', u'O'),
#   ('said', 'VBD', u'O'),
#   ('mr.', 'JJ', u'O'),
#   ('musk', 'NNP', u'O'),
#   ('had', 'VBD', u'O'),
#   ('rejected', 'VBN', u'O'),
#   ('on', 'IN', u'O'),
#   ('thursday', 'NN', u'B-NP'),
#   ('which', 'WDT', u'O'),
#   ('called', 'VBD', u'O'),
#   ('for', 'IN', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('twoyear', 'JJ', u'I-NP'),
#   ('bar', 'NN', u'I-NP'),
#   ('on', 'IN', u'O'),
#   ('serving', 'VBG', u'O'),
#   ('as', 'IN', u'O'),
#   ('chairman', 'NN', u'B-NP'),
#   ('and', 'CC', u'O'),
#   ('a', 'DT', u'O'),
#   ('$', '$', u'O'),
#   ('10', 'CD', u'O'),
#   ('million', 'CD', u'O'),
#   ('fine.tesla', 'NN', u'B-NP'),
#   ('which', 'WDT', u'O'),
#   ('is', 'VBZ', u'O'),
#   ('also', 'RB', u'O'),
#   ('settling', 'VBG', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'regulators served a subpoena on the company seeking information and moved to take testimony from mr. musk and others at the company people familiar with the matter said.negotiations toward an initial settlement began about a week ago after the s.e.c.': [('regulators',
#    'NNS',
#    u'O'),
#   ('served', 'VBD', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('subpoena', 'NN', u'I-NP'),
#   ('on', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('company', 'NN', u'I-NP'),
#   ('seeking', 'VBG', u'O'),
#   ('information', 'NN', u'B-NP'),
#   ('and', 'CC', u'O'),
#   ('moved', 'VBD', u'O'),
#   ('to', 'TO', u'O'),
#   ('take', 'VB', u'O'),
#   ('testimony', 'NN', u'B-NP'),
#   ('from', 'IN', u'O'),
#   ('mr.', 'JJ', u'O'),
#   ('musk', 'NNP', u'O'),
#   ('and', 'CC', u'O'),
#   ('others', 'NNS', u'O'),
#   ('at', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('company', 'NN', u'I-NP'),
#   ('people', 'NNS', u'O'),
#   ('familiar', 'JJ', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('matter', 'NN', u'I-NP'),
#   ('said.negotiations', 'NNS', u'O'),
#   ('toward', 'IN', u'O'),
#   ('an', 'DT', u'B-NP'),
#   ('initial', 'JJ', u'I-NP'),
#   ('settlement', 'NN', u'I-NP'),
#   ('began', 'VBD', u'O'),
#   ('about', 'IN', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('week', 'NN', u'I-NP'),
#   ('ago', 'RB', u'O'),
#   ('after', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'sued mr. musk his lawyers continued to talk to him about moving forward with a settlement and eventually he agreed this person said.in the meantime mr. musk had conversations with investors and friends like mark cuban an entrepreneur who has had his own battles with the s.e.c.': [('sued',
#    'VBN',
#    u'O'),
#   ('mr.', 'JJ', u'O'),
#   ('musk', 'NNP', u'O'),
#   ('his', 'PRP$', u'O'),
#   ('lawyers', 'NNS', u'O'),
#   ('continued', 'VBD', u'O'),
#   ('to', 'TO', u'O'),
#   ('talk', 'VB', u'O'),
#   ('to', 'TO', u'O'),
#   ('him', 'PRP', u'O'),
#   ('about', 'IN', u'O'),
#   ('moving', 'VBG', u'O'),
#   ('forward', 'RB', u'O'),
#   ('with', 'IN', u'O'),
#   ('a', 'DT', u'B-NP'),
#   ('settlement', 'NN', u'I-NP'),
#   ('and', 'CC', u'O'),
#   ('eventually', 'RB', u'O'),
#   ('he', 'PRP', u'O'),
#   ('agreed', 'VBD', u'O'),
#   ('this', 'DT', u'B-NP'),
#   ('person', 'NN', u'I-NP'),
#   ('said.in', 'VBD', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('meantime', 'NN', u'I-NP'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'NNP', u'O'),
#   ('had', 'VBD', u'O'),
#   ('conversations', 'NNS', u'O'),
#   ('with', 'IN', u'O'),
#   ('investors', 'NNS', u'O'),
#   ('and', 'CC', u'O'),
#   ('friends', 'NNS', u'O'),
#   ('like', 'IN', u'O'),
#   ('mark', 'NN', u'B-NP'),
#   ('cuban', 'VBP', u'O'),
#   ('an', 'DT', u'B-NP'),
#   ('entrepreneur', 'NN', u'I-NP'),
#   ('who', 'WP', u'O'),
#   ('has', 'VBZ', u'O'),
#   ('had', 'VBD', u'O'),
#   ('his', 'PRP$', u'O'),
#   ('own', 'JJ', u'O'),
#   ('battles', 'NNS', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')],
#  'the amount of stock being bought by mr. musk matches the penalty the company has to pay under the settlement which was filed in federal court in manhattan.the s.e.c.': [('the',
#    'DT',
#    u'B-NP'),
#   ('amount', 'NN', u'I-NP'),
#   ('of', 'IN', u'O'),
#   ('stock', 'NN', u'B-NP'),
#   ('being', 'VBG', u'O'),
#   ('bought', 'VBN', u'O'),
#   ('by', 'IN', u'O'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'NN', u'B-NP'),
#   ('matches', 'VBZ', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('penalty', 'NN', u'I-NP'),
#   ('the', 'DT', u'B-NP'),
#   ('company', 'NN', u'I-NP'),
#   ('has', 'VBZ', u'O'),
#   ('to', 'TO', u'O'),
#   ('pay', 'VB', u'O'),
#   ('under', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('settlement', 'NN', u'I-NP'),
#   ('which', 'WDT', u'O'),
#   ('was', 'VBD', u'O'),
#   ('filed', 'VBN', u'O'),
#   ('in', 'IN', u'O'),
#   ('federal', 'JJ', u'B-NP'),
#   ('court', 'NN', u'I-NP'),
#   ('in', 'IN', u'O'),
#   ('manhattan.the', 'NN', u'B-NP'),
#   ('s.e.c', 'NN', u'B-NP'),
#   ('.', '.', u'O')],
#  'will allow him to remain as chief executive something he could have jeopardized if he had gone to battle with the agency.it is not clear why mr. musk changed his mind so quickly.people familiar with the situation who were not authorized to speak publicly on the matter said lawyers for mr. musk and the company moved to reopen the talks with the s.e.c.': [('will',
#    'MD',
#    u'O'),
#   ('allow', 'VB', u'O'),
#   ('him', 'PRP', u'O'),
#   ('to', 'TO', u'O'),
#   ('remain', 'VB', u'O'),
#   ('as', 'IN', u'O'),
#   ('chief', 'JJ', u'B-NP'),
#   ('executive', 'NN', u'I-NP'),
#   ('something', 'NN', u'B-NP'),
#   ('he', 'PRP', u'O'),
#   ('could', 'MD', u'O'),
#   ('have', 'VB', u'O'),
#   ('jeopardized', 'VBN', u'O'),
#   ('if', 'IN', u'O'),
#   ('he', 'PRP', u'O'),
#   ('had', 'VBD', u'O'),
#   ('gone', 'VBN', u'O'),
#   ('to', 'TO', u'O'),
#   ('battle', 'NN', u'B-NP'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('agency.it', 'NN', u'I-NP'),
#   ('is', 'VBZ', u'O'),
#   ('not', 'RB', u'O'),
#   ('clear', 'JJ', u'O'),
#   ('why', 'WRB', u'O'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'NN', u'B-NP'),
#   ('changed', 'VBD', u'O'),
#   ('his', 'PRP$', u'O'),
#   ('mind', 'NN', u'B-NP'),
#   ('so', 'RB', u'O'),
#   ('quickly.people', 'JJ', u'O'),
#   ('familiar', 'JJ', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('situation', 'NN', u'I-NP'),
#   ('who', 'WP', u'O'),
#   ('were', 'VBD', u'O'),
#   ('not', 'RB', u'O'),
#   ('authorized', 'VBN', u'O'),
#   ('to', 'TO', u'O'),
#   ('speak', 'VB', u'O'),
#   ('publicly', 'RB', u'O'),
#   ('on', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('matter', 'NN', u'I-NP'),
#   ('said', 'VBD', u'O'),
#   ('lawyers', 'NNS', u'O'),
#   ('for', 'IN', u'O'),
#   ('mr.', 'NN', u'B-NP'),
#   ('musk', 'NN', u'B-NP'),
#   ('and', 'CC', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('company', 'NN', u'I-NP'),
#   ('moved', 'VBD', u'O'),
#   ('to', 'TO', u'O'),
#   ('reopen', 'VB', u'O'),
#   ('the', 'DT', u'O'),
#   ('talks', 'NNS', u'O'),
#   ('with', 'IN', u'O'),
#   ('the', 'DT', u'B-NP'),
#   ('s.e.c', 'NN', u'I-NP'),
#   ('.', '.', u'O')]}

# %%
keywords = []

for y in tagged.keys() :
    for i in range(len(tagged[y])) :
        if tagged[y][i][1] == 'NN':
            if tagged[y][i][2] == 'B-NP' or 'I-NP':
                keywords.append(tagged[y][i][0])
            else :
                pass
        else :
            pass

# %%
key_words = {}

for key_word in keywords :
    if key_word in key_words.keys() :
        key_words[key_word] += 1
    else :
        key_words[key_word] = 1

# %%
keys = {}

for kw in key_words.keys():
    if key_words[kw] > 1 :
        keys[kw] = key_words[kw]
    else :
        pass

# %%
keys
# Out:
# {'chairman': 2,
#  'charge': 2,
#  'company': 7,
#  'court': 2,
#  'deal': 4,
#  'fraud': 2,
#  'friday': 2,
#  'matter': 2,
#  'mr.': 9,
#  'musk': 5,
#  'person': 2,
#  's.e.c': 10,
#  'settlement': 10,
#  'situation': 2,
#  'spokesman': 2,
#  'stock': 3,
#  'tesla': 6,
#  'thursday': 2}
